# %%
import os
import tkinter, tkinter.filedialog#[開く]で元画像フォルダー選択するために必要なライブラリ
from PIL import Image, ImageDraw, ImageFilter#画像処理に必要なライブラリ
import time
import math

import sys
import os
def resource_path(relative_path):
    
    if hasattr(sys, '_MEIPASS'):
        return os.path.join(sys._MEIPASS, relative_path)
    
    return os.path.join(os.path.abspath("."), relative_path)



WM_FILE_T1 = resource_path("0000A4TN.jpg")
WM_FILE_T2 = resource_path("0000A4TF.jpg")
WM_FILE_T3 = resource_path("0000A4TV.jpg")
WM_FILE_T4 = resource_path("0000A4TP.jpg")
WM_FILE_T5 = resource_path("0000A4TState.jpg")
WM_FILE_T6 = resource_path("0000A4TSyoko.jpg")


WM_T1 = Image.open(WM_FILE_T1)
WM_T2 = Image.open(WM_FILE_T2)
WM_T3 = Image.open(WM_FILE_T3)
WM_T4 = Image.open(WM_FILE_T4)
WM_T5 = Image.open(WM_FILE_T5)
WM_T6 = Image.open(WM_FILE_T6)

#共通　ページ名定義
pagename50 = ['0000','0001','0203','0405','0607','0809','1011','1213','1415','1617','1819','2021','2223','2425','2600']
pagename75 = ['0000','0001','0203','0405','0607','0809','1011','1213','1415','1617','1819','2021','2223','2425','2627','2829','3000']

tuple_basecolor = (0xff, 0xff, 0xff, 255)#R,G,B,α

#各種アルバムの定義

#------------------------------------------------------------------------------
#ナチュラルA4縦
base_A4TN_width = 5079
base_A4TN_height = 3378
base_A4TN_dpi= 300
cover_A4TN_width = 5469
cover_A4TN_height = 3614
cover_A4TN_dpi = 300


mag_A4TN = 0.8 #縦　中身画像倍率
mag_A4TN2 = 0.6 #横　中身画像倍率0.614

mag_cover_A4TN = 0.85 #縦　表紙画像倍率
mag_cover_A4TN2 = 0.65 #横　表紙画像倍率
mag_cover2_A4TN = 0.3 #縦　裏表紙画像倍率
mag_cover2_A4TN2 = 0.3 #横　裏表紙画像倍率

cover_offset_A4TN_x = int(cover_A4TN_width/4*3)#表紙画像
cover_offset_A4TN_y = int(cover_A4TN_height/2)#表紙画像
cover_offset_A4TN_x2 = int(cover_A4TN_width/4*3) #表紙画像オフセット横画像4025
cover_offset_A4TN_y2 = int(cover_A4TN_height/2)#表紙画像オフセット横画像1140

cover2_offset_A4TN_x = int(cover_A4TN_width/4) #裏表紙画像オフセット縦画像
cover2_offset_A4TN_y = int(cover_A4TN_height/2)#裏表紙画像オフセット縦画像
cover2_offset_A4TN_x2 = int(cover_A4TN_width/4)#裏表紙画像オフセット横画像
cover2_offset_A4TN_y2 = int(cover_A4TN_height/2) #裏表紙画像オフセット横画像
#------------------------------------------------------------------------------


#------------------------------------------------------------------------------
#ファインバリューレザープレミアム共通部分
base_A4TC_width = 5561
base_A4TC_height = 3962
base_A4TC_dpi= 330
cover_A4TC_width = 7465
cover_A4TC_height = 5087
cover_A4TC_dpi = 400

mag_A4TC = 0.9 #縦　中身画像倍率
mag_A4TC2 = 0.65 #横　中身画像倍率0.614
#------------------------------------------------------------------------------


#------------------------------------------------------------------------------
#ファイン固有

mag_cover_A4TF = 0.7 #縦　表紙画像倍率
mag_cover_A4TF2 = 0.7 #横　表紙画像倍率
mag_cover2_A4TF = 0.3 #縦　裏表紙画像倍率
mag_cover2_A4TF2 = 0.3 #横　裏表紙画像倍率

cover_offset_A4TF_x = int(cover_A4TC_width/4*3)-70#表紙画像
cover_offset_A4TF_y = int(cover_A4TC_height/2)-250#表紙画像
cover_offset_A4TF_x2 = int(cover_A4TC_width/4*3) #表紙画像オフセット横画像4025
cover_offset_A4TF_y2 = int(cover_A4TC_height/2)#表紙画像オフセット横画像1140

cover2_offset_A4TF_x = int(cover_A4TC_width/4) #裏表紙画像オフセット縦画像
cover2_offset_A4TF_y = int(cover_A4TC_height/2)#裏表紙画像オフセット縦画像
cover2_offset_A4TF_x2 = int(cover_A4TC_width/4)#裏表紙画像オフセット横画像
cover2_offset_A4TF_y2 = int(cover_A4TC_height/2) #裏表紙画像オフセット横画像
#------------------------------------------------------------------------------


#------------------------------------------------------------------------------
#バリュー固有

mag_cover_A4TV = 1.4 #縦　表紙画像倍率 はみ出し仕様
mag_cover_A4TV2 = 0.9 #横　表紙画像倍率

cover_offset_A4TV_x = int(cover_A4TC_width/4*3)#表紙画像
cover_offset_A4TV_y = int(cover_A4TC_height/2)#表紙画像
cover_offset_A4TV_x2 = int(cover_A4TC_width/4*3) #表紙画像オフセット横画像4025
cover_offset_A4TV_y2 = int(cover_A4TC_height/2)#表紙画像オフセット横画像1140
#------------------------------------------------------------------------------

#------------------------------------------------------------------------------
#プレミアム固有

mag_cover_A4TP = 0.85 #縦　表紙画像倍率
mag_cover_A4TP2 = 0.65 #横　表紙画像倍率
mag_cover2_A4TP = 0.3 #縦　裏表紙画像倍率
mag_cover2_A4TP2 = 0.3 #横　裏表紙画像倍率

cover_offset_A4TP_x = int(cover_A4TC_width/4*3)#表紙画像
cover_offset_A4TP_y = int(cover_A4TC_height/2)#表紙画像
cover_offset_A4TP_x2 = int(cover_A4TC_width/4*3) #表紙画像オフセット横画像4025
cover_offset_A4TP_y2 = int(cover_A4TC_height/2)#表紙画像オフセット横画像1140

cover2_offset_A4TP_x = int(cover_A4TC_width/4) #裏表紙画像オフセット縦画像
cover2_offset_A4TP_y = int(cover_A4TC_height/2)#裏表紙画像オフセット縦画像
cover2_offset_A4TP_x2 = int(cover_A4TC_width/4)#裏表紙画像オフセット横画像
cover2_offset_A4TP_y2 = int(cover_A4TC_height/2) #裏表紙画像オフセット横画像
#------------------------------------------------------------------------------

#------------------------------------------------------------------------------
#スタイリッシュ
base_A4TS_width = 5043
base_A4TS_height = 3378
base_A4TS_dpi= 300
cover_A4TS_width = 7244
cover_A4TS_height = 4819
cover_A4TS_dpi = 400


mag_A4TS = 0.8 #縦　中身画像倍率
mag_A4TS2 = 0.6 #横　中身画像倍率0.614

mag_cover_A4TS = 0.85 #縦　表紙画像倍率
mag_cover_A4TS2 = 0.68 #横　表紙画像倍率

cover_offset_A4TS_x = int(cover_A4TS_width/4*3)+15#表紙画像
cover_offset_A4TS_y = int(cover_A4TS_height/2)-40#表紙画像
cover_offset_A4TS_x2 = int(cover_A4TS_width/4*3)+20 #表紙画像オフセット横画像4025
cover_offset_A4TS_y2 = int(cover_A4TS_height/2)+35#表紙画像オフセット横画像1140
#------------------------------------------------------------------------------








#表紙元画像フォルダー選択
root = tkinter.Tk()
root.withdraw()
msg = '画像フォルダーを選択してください。'
img_dir_path = tkinter.filedialog.askdirectory(title=msg)
if (not img_dir_path): #[キャンセル]クリック時の処理
    print('フォルダーを選んでください。')
    sys.exit()
#表紙元画像フォルダー選択ここまで



folder_list = os.listdir(img_dir_path)#フォルダ名のリストを作成

i = 0

while i < len(folder_list) :
    

    other_path = os.path.join(img_dir_path,folder_list[i],"other")

    directory = os.listdir(other_path)

    sorted_directory = sorted(directory )


   
    
    
#コモン変数に取得したアルバム種別を代入    

    subdirname = os.path.basename(os.path.dirname(other_path))#今回の作業用フォルダ名取得
    print(subdirname, end=" ")
    ifleather = (subdirname[-1])#レザーは末尾が14
    
    #coverフォルダの有無でレザーを判定
    cover_chk = os.path.join(img_dir_path,folder_list[i],"cover")
    
    albumname = (subdirname[-2:])
    if albumname == '50':
        pagename = pagename50
    elif albumname == '75':
        pagename = pagename75
    else:
        print('規定のアルバムではありません')
    
    print('{}カット'.format(albumname), end=" ")
    albumkind = (subdirname[-11])#後ろから11文字目が識別子(f,v,n,m)
    if albumkind == 'f' or albumkind == 'v' or  (os.path.exists(cover_chk) == False):#ファイン、バリュー、レザー
        if albumkind == 'f':#ファイン固有の値
            print('アルバムファイン', end=" ")
            cov_base_tate = WM_T2#表紙の下地画像を呼び出し_めんどいので文字の位置縦横共通
            cov_base_yoko = WM_T2#表紙の下地画像を呼び出し_めんどいので文字の位置縦横共通
            cover_offset_common_x = cover_offset_A4TF_x #表紙画像オフセット縦画像
            cover_offset_common_y = cover_offset_A4TF_y #表紙画像オフセット縦画像
            cover_offset_common_x2 = cover_offset_A4TF_x2 #表紙画像オフセット横画像
            cover_offset_common_y2 = cover_offset_A4TF_y2 #表紙画像オフセット横画像
            cover2_offset_common_x = cover2_offset_A4TF_x #裏表紙画像オフセット縦画像
            cover2_offset_common_y = cover2_offset_A4TF_y #裏表紙画像オフセット縦画像
            cover2_offset_common_x2 = cover2_offset_A4TF_x2 #裏表紙画像オフセット横画像
            cover2_offset_common_y2 = cover2_offset_A4TF_y2 #裏表紙画像オフセット横画像
            
            mag_cover_common = mag_cover_A4TF
            mag_cover_common2 = mag_cover_A4TF2
            mag_cover2_common = mag_cover2_A4TF
            mag_cover2_common2 = mag_cover2_A4TF2
            
            
            
        elif albumkind == 'v':#バリュー固有の値
            print('バリューアルバム', end=" ")
            cov_base_tate = WM_T3#表紙の下地画像を呼び出し_めんどいので文字の位置縦横共通
            cov_base_yoko = WM_T3#表紙の下地画像を呼び出し_めんどいので文字の位置縦横共通
            cover_offset_common_x = cover_offset_A4TV_x #表紙画像オフセット縦画像
            cover_offset_common_y = cover_offset_A4TV_y #表紙画像オフセット縦画像
            cover_offset_common_x2 = cover_offset_A4TV_x2 #表紙画像オフセット横画像
            cover_offset_common_y2 = cover_offset_A4TV_y2 #表紙画像オフセット横画像
            
            mag_cover_common = mag_cover_A4TV
            mag_cover_common2 = mag_cover_A4TV2
            mag_cover2_common = mag_cover2_A4TN#裏表紙ないタイプもダミー定義
            mag_cover2_common2 = mag_cover2_A4TN2#裏表紙ないタイプもダミー定義
        elif  (os.path.exists(cover_chk) == False):#レザー固有の値
            print('レザーアルバム', end=" ")
            #レザー固有の値は特になし
    
            
        #ファイン、バリュー、レザーの共通値はファインの定義を使用
        mag_image = float(mag_A4TC)
        mag_image2 = float(mag_A4TC2)

        cover_A4T_width = cover_A4TC_width
        cover_A4T_height = cover_A4TC_height
        cover_A4T_dpi = cover_A4TC_dpi
        base_A4T_width = base_A4TC_width
        base_A4T_height = base_A4TC_height
        base_A4T_dpi= base_A4TC_dpi
        mag_common = mag_A4TC
        mag_common2 = mag_A4TC2
        
    elif albumkind == 'n':#ナチュラルA4T
        print('ナチュラルアルバムA4縦', end=" ")
        cov_base_tate = WM_T1#表紙の下地画像を呼び出し_めんどいので文字の位置縦横共通
        cov_base_yoko = WM_T1#表紙の下地画像を呼び出し_めんどいので文字の位置縦横共通
        cover_offset_common_x = cover_offset_A4TN_x #表紙画像オフセット縦画像
        cover_offset_common_y = cover_offset_A4TN_y #表紙画像オフセット縦画像
        cover_offset_common_x2 = cover_offset_A4TN_x2 #表紙画像オフセット横画像
        cover_offset_common_y2 = cover_offset_A4TN_y2 #表紙画像オフセット横画像
        cover2_offset_common_x = cover2_offset_A4TN_x #裏表紙画像オフセット縦画像
        cover2_offset_common_y = cover2_offset_A4TN_y #裏表紙画像オフセット縦画像
        cover2_offset_common_x2 = cover2_offset_A4TN_x2 #裏表紙画像オフセット横画像
        cover2_offset_common_y2 = cover2_offset_A4TN_y2 #裏表紙画像オフセット横画像
        mag_cover_common = mag_cover_A4TN
        mag_cover_common2 = mag_cover_A4TN2
        mag_cover2_common = mag_cover2_A4TN
        mag_cover2_common2 = mag_cover2_A4TN2
        
        cover_A4T_width = cover_A4TN_width
        cover_A4T_height = cover_A4TN_height
        cover_A4T_dpi = cover_A4TN_dpi
        base_A4T_width = base_A4TN_width
        base_A4T_height = base_A4TN_height
        base_A4T_dpi= base_A4TN_dpi
        

        mag_image = float(mag_A4TN)
        mag_image2 = float(mag_A4TN2)

        mag_common = mag_A4TN
        mag_common2 = mag_A4TN2


    else:#上記以外はスタイリッシュアルバムLite14
        print('スタイリッシュアルバム全カット', end=" ")
        cov_base_tate = WM_T5#表紙の下地画像を呼び出し
        cov_base_yoko = WM_T6#表紙の下地画像を呼び出し
        cover_offset_common_x = cover_offset_A4TS_x #表紙画像オフセット縦画像
        cover_offset_common_y = cover_offset_A4TS_y #表紙画像オフセット縦画像
        cover_offset_common_x2 = cover_offset_A4TS_x2 #表紙画像オフセット横画像
        cover_offset_common_y2 = cover_offset_A4TS_y2 #表紙画像オフセット横画像
        cover2_offset_common_x = cover2_offset_A4TF_x #裏表紙ないタイプもダミー定義
        cover2_offset_common_y = cover2_offset_A4TF_y #裏表紙ないタイプもダミー定義
        cover2_offset_common_x2 = cover2_offset_A4TF_x2 #裏表紙ないタイプもダミー定義
        cover2_offset_common_y2 = cover2_offset_A4TF_y2 #裏表紙ないタイプもダミー定義
        mag_cover_common = mag_cover_A4TS
        mag_cover_common2 = mag_cover_A4TS2
        mag_cover2_common = mag_cover2_A4TN#裏表紙ないタイプもダミー定義
        mag_cover2_common2 = mag_cover2_A4TN2#裏表紙ないタイプもダミー定義
        
        cover_A4T_width = cover_A4TS_width
        cover_A4T_height = cover_A4TS_height
        cover_A4T_dpi = cover_A4TS_dpi
        base_A4T_width = base_A4TS_width
        base_A4T_height = base_A4TS_height
        base_A4T_dpi= base_A4TS_dpi
        

        mag_image = float(mag_A4TS)
        mag_image2 = float(mag_A4TS2)

        mag_common = mag_A4TS

    if (os.path.exists(cover_chk) == True):#レザー以外なら表紙を作る
    
    
        
        #表紙
        cover_path = os.path.join(img_dir_path,folder_list[i],"cover")
        cover_directory = os.listdir(cover_path)
        cov = Image.open(os.path.join(img_dir_path,folder_list[i],"cover",cover_directory[0]))
        cov_width, cov_height = cov.size
        base = Image.new('RGB', (cover_A4T_width, cover_A4T_height), tuple_basecolor)#下地の白画像をbaseという名前で生成
        back_im = base.copy()#共通
        back_im_tate = cov_base_tate.copy()
        back_im_yoko = cov_base_yoko.copy()
        resize_cov = cov.resize((int(cov_width * mag_cover_common), int(cov_height * mag_cover_common)),resample=Image.LANCZOS)#表紙縦
        resize_cov2 = cov.resize((int(cov_width * mag_cover_common2), int(cov_height * mag_cover_common2)),resample=Image.LANCZOS)#表紙横
        resize2_cov = cov.resize((int(cov_width * mag_cover2_common), int(cov_height * mag_cover2_common)),resample=Image.LANCZOS)#裏表紙縦
        resize2_cov2 = cov.resize((int(cov_width * mag_cover2_common2), int(cov_height * mag_cover2_common2)),resample=Image.LANCZOS)#裏表紙横

        if cov_width < cov_height:
            if  6800-10 < int(cov_width) + int(cov_height)  < 6800 + 10 and 290 < cov.info['dpi'][0] < 360:#縦横のピクセルが規定値±5の場合またはdpiが290～360の間
                back_im_tate.paste(resize_cov, ((cover_offset_common_x -int(cov_width * mag_cover_common/2), cover_offset_common_y -int(cov_height * mag_cover_common/2))))#縦
                if albumkind == 'f' or albumkind == 'n':#ファインとナチュラルは裏表紙の小写真あり
                    back_im_tate.paste(resize2_cov, (cover2_offset_common_x -int(cov_width * mag_cover2_common/2), cover2_offset_common_y -int(cov_height * mag_cover2_common/2)))#縦裏表紙
                else:
                    print('裏表紙小画像なし', end=" ")
                back_im_tate.save(os.path.join(img_dir_path,folder_list[i], "0000.jpg"), quality=100, dpi=(cover_A4T_dpi, cover_A4T_dpi))
            else:
                back_im_tate.paste(resize_cov, (cover_offset_common_x, cover_offset_common_y))#縦
                if albumkind == 'f' or albumkind == 'n':#ファインとナチュラルは裏表紙の小写真あり
                    back_im_tate.paste(resize2_cov, (cover2_offset_common_x, cover2_offset_common_y))#縦裏表紙
                else:
                    print('裏表紙小画像なし', end=" ")
                back_im_tate.save(os.path.join(img_dir_path,folder_list[i], "0000【エラー】.jpg"), quality=100, dpi=(cover_A4T_dpi, cover_A4T_dpi))

        else:
            if  6800-10 <int(cov_width) + int(cov_height)  < 6800 + 10 and 290 < cov.info['dpi'][0] <360:#縦横のピクセルが規定値±5の場合またはdpiが290～360の間
                back_im_yoko.paste(resize_cov2, (cover_offset_common_x2 -int(cov_width * mag_cover_common2/2), cover_offset_common_y2 -int(cov_height * mag_cover_common2/2)))#横
                if albumkind == 'f' or albumkind == 'n':#ファインとナチュラルは裏表紙の小写真あり
                    back_im_yoko.paste(resize2_cov2, (cover2_offset_common_x2 -int(cov_width * mag_cover2_common2/2), cover2_offset_common_y2 -int(cov_height * mag_cover2_common2/2)))#横裏表紙
                else:
                    print('裏表紙小画像なし', end=" ")
                back_im_yoko.save(os.path.join(img_dir_path,folder_list[i], "0000.jpg"), quality=100, dpi=(cover_A4T_dpi, cover_A4T_dpi))
            else:
                back_im_yoko.paste(resize_cov2, (cover_offset_common_x2, cover_offset_common_y2))#横
                if albumkind == 'f' or albumkind == 'n':#ファインとナチュラルは裏表紙の小写真あり
                    back_im_yoko.paste(resize2_cov2, (cover2_offset_common_x2, cover2_offset_common_y2))#横裏表紙
                else:
                    print('裏表紙小画像なし', end=" ")
                back_im_yoko.save(os.path.join(img_dir_path,folder_list[i], "0000【エラー】.jpg"), quality=100, dpi=(cover_A4T_dpi, cover_A4T_dpi))

#表紙ここまで       

    else:
        print('レザーは表紙なし', end=" ")
        
    def single1(j,n,x):#片ページに１枚、片ページは空白の見開きをページを定義(最初や最後のページに使用)X=1は左2600か3000、X=3は右0001
        im = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j]))
        im_width, im_height = im.size
        base = Image.new('RGB', (base_A4T_width, base_A4T_height), tuple_basecolor)#下地の白画像をbaseという名前で生成
        if im_width < im_height:
            resize_im = im.resize((int(im_width * mag_image) , int(im_height * mag_image)),resample=Image.LANCZOS)#縦
            base.paste(resize_im, (int(base_A4T_width/4*x -im_width*mag_image/2) , int(base_A4T_height/2 -im_height*mag_image/2)))#縦
            
        elif im_width > im_height:
            resize_im = im.resize((int(im_width * mag_image2) , int(im_height * mag_image2)),resample=Image.LANCZOS)#横
            base.paste(resize_im, (int(base_A4T_width/4*x -im_width*mag_image2/2) , int(base_A4T_height/2 -im_height*mag_image2/2)))#横
            
        base.save(os.path.join(img_dir_path,folder_list[i], pagename[n]+".jpg"), quality=100, dpi=(base_A4T_dpi, base_A4T_dpi))

    def r3(j,n,mx,my):#右が大きい3枚
        
        chk_im = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j])) #このグループの1番目を判定するため読む
        chk_im_width, chk_im_height = chk_im.size
        chk_im2 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j+1])) #このグループの2番目を判定するため読む
        chk_im2_width, chk_im2_height = chk_im2.size
        chk_im3 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j+2])) #このグループの3番目を判定するため読む
        chk_im3_width, chk_im3_height = chk_im3.size
        
        
        if chk_im_width < chk_im_height:#1番目縦
            im = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j+2]))
            im2 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j+1]))
            im3 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j]))
        elif chk_im2_width < chk_im2_height:#2番目縦
            im = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j]))
            im2 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j+2]))
            im3 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j+1]))
        elif chk_im3_width < chk_im3_height:#3番目縦
            im = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j]))
            im2 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j+1]))
            im3 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j+2]))
        else:
            im = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j]))
            im2 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j+1]))
            im3 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j+2]))

        base = Image.new('RGB', (base_A4T_width, base_A4T_height), tuple_basecolor)#下地の白画像をbaseという名前で生成

        im_width, im_height = im.size
        if im_width < im_height:
            resize_im = im.resize((int(im_width * mag_image*my) , int(im_height * mag_image*my)),resample=Image.LANCZOS)#縦
            base.paste(resize_im, (int(base_A4T_width/4 -im_width*mag_image*my/2) , int(base_A4T_height/4 -im_height*mag_image*my/2)))#縦
            
        elif im_width > im_height:
            resize_im = im.resize((int(im_width * mag_image2*mx) , int(im_height * mag_image2*mx)),resample=Image.LANCZOS)#横
            base.paste(resize_im, (int(base_A4T_width/4 -im_width*mag_image2*mx/2) , int(base_A4T_height/4 -im_height*mag_image2*mx/2)))#横
        
        im2_width, im2_height = im2.size
        if im2_width < im2_height:
            resize_im2 = im2.resize((int(im2_width * mag_image*my) , int(im2_height * mag_image*my)),resample=Image.LANCZOS)#縦
            base.paste(resize_im2, (int(base_A4T_width/4 -im2_width*mag_image*my/2) , int(base_A4T_height/4*3 -im2_height*mag_image*my/2)))#縦
            
        elif im2_width > im2_height:
            resize_im2 = im2.resize((int(im2_width * mag_image2*mx) , int(im2_height * mag_image2*mx)),resample=Image.LANCZOS)#横
            base.paste(resize_im2, (int(base_A4T_width/4 -im2_width*mag_image2*mx/2) , int(base_A4T_height/4*3 -im2_height*mag_image2*mx/2)))#横

        im3_width, im3_height = im3.size
        if im3_width < im3_height:
            resize_im3 = im3.resize((int(im3_width * mag_image) , int(im3_height * mag_image)),resample=Image.LANCZOS)#縦
            base.paste(resize_im3, (int(base_A4T_width/4*3 -im3_width*mag_image/2) , int(base_A4T_height/2 -im3_height*mag_image/2)))#縦
            
        elif im3_width > im3_height:
            resize_im3 = im3.resize((int(im3_width * mag_image2) , int(im3_height * mag_image2)),resample=Image.LANCZOS)#横
            base.paste(resize_im3, (int(base_A4T_width/4*3 -im3_width*mag_image2/2) , int(base_A4T_height/2 -im3_height*mag_image2/2)))#横

        base.save(os.path.join(img_dir_path,folder_list[i], pagename[n]+".jpg"), quality=100, dpi=(base_A4T_dpi, base_A4T_dpi))

    def l3(j,n,mx,my):#左が大きい3枚
        chk_im = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j])) #このグループの1番目を判定するため読む
        chk_im_width, chk_im_height = chk_im.size
        chk_im2 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j+1])) #このグループの2番目を判定するため読む
        chk_im2_width, chk_im2_height = chk_im2.size
        chk_im3 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j+2])) #このグループの3番目を判定するため読む
        chk_im3_width, chk_im3_height = chk_im3.size
        
        
        if chk_im_width < chk_im_height:#1番目縦
            im = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j]))
            im2 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j+1]))
            im3 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j+2]))
        elif chk_im2_width < chk_im2_height:#2番目縦
            im = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j+1]))
            im2 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j]))
            im3 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j+2]))
        elif chk_im3_width < chk_im3_height:#3番目縦
            im = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j+2]))
            im2 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j+1]))
            im3 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j]))
        else:
            im = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j]))
            im2 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j+1]))
            im3 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j+2]))
            
            
        base = Image.new('RGB', (base_A4T_width, base_A4T_height), tuple_basecolor)#下地の白画像をbaseという名前で生成

        im_width, im_height = im.size
        if im_width < im_height:
            resize_im = im.resize((int(im_width * mag_image) , int(im_height * mag_image)),resample=Image.LANCZOS)#縦
            base.paste(resize_im, (int(base_A4T_width/4 -im_width*mag_image/2) , int(base_A4T_height/2 -im_height*mag_image/2)))#縦
            
        elif im_width > im_height:
            resize_im = im.resize((int(im_width * mag_image2) , int(im_height * mag_image2)),resample=Image.LANCZOS)#横
            base.paste(resize_im, (int(base_A4T_width/4 -im_width*mag_image2/2) , int(base_A4T_height/2 -im_height*mag_image2/2)))#横

        im2_width, im2_height = im2.size
        if im2_width < im2_height:
            resize_im2 = im2.resize((int(im2_width * mag_image*my) , int(im2_height * mag_image*my)),resample=Image.LANCZOS)#縦
            base.paste(resize_im2, (int(base_A4T_width/4*3 -im2_width*mag_image*my/2) , int(base_A4T_height/4 -im2_height*mag_image*my/2)))#縦
            
        elif im2_width > im2_height:
            resize_im2 = im2.resize((int(im2_width * mag_image2*mx) , int(im2_height * mag_image2*mx)),resample=Image.LANCZOS)#横
            base.paste(resize_im2, (int(base_A4T_width/4*3 -im2_width*mag_image2*mx/2) , int(base_A4T_height/4 -im2_height*mag_image2*mx/2)))#横

        im3_width, im3_height = im3.size
        if im3_width < im3_height:
            resize_im3 = im3.resize((int(im3_width * mag_image*my) , int(im3_height * mag_image*my)),resample=Image.LANCZOS)#縦
            base.paste(resize_im3, (int(base_A4T_width/4*3 -im3_width*mag_image*my/2) , int(base_A4T_height/4*3 -im3_height*mag_image*my/2)))#縦
            
        elif im3_width > im3_height:
            resize_im3 = im3.resize((int(im3_width * mag_image2*mx) , int(im3_height * mag_image2*mx)),resample=Image.LANCZOS)#横
            base.paste(resize_im3, (int(base_A4T_width/4*3 -im3_width*mag_image2*mx/2) , int(base_A4T_height/4*3 -im3_height*mag_image2*mx/2)))#横

        base.save(os.path.join(img_dir_path,folder_list[i], pagename[n]+".jpg"), quality=100, dpi=(base_A4T_dpi, base_A4T_dpi))
        
    def n4(j,n,mx,my):#4枚

        base = Image.new('RGB', (base_A4T_width, base_A4T_height), tuple_basecolor)#下地の白画像をbaseという名前で生成

        im = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j]))
        im_width, im_height = im.size
        if im_width < im_height:
            resize_im = im.resize((int(im_width * mag_image*my) , int(im_height * mag_image*my)),resample=Image.LANCZOS)#縦
            base.paste(resize_im, (int(base_A4T_width/4 -im_width*mag_image*my/2) , int(base_A4T_height/4 -im_height*mag_image*my/2)))#縦
            
        elif im_width > im_height:
            resize_im = im.resize((int(im_width * mag_image2*mx) , int(im_height * mag_image2*mx)),resample=Image.LANCZOS)#横
            base.paste(resize_im, (int(base_A4T_width/4 -im_width*mag_image2*mx/2) , int(base_A4T_height/4 -im_height*mag_image2*mx/2)))#横
            
        j = j + 1
        im2 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j]))
        im2_width, im2_height = im2.size
        if im2_width < im2_height:
            resize_im2 = im2.resize((int(im2_width * mag_image*my) , int(im2_height * mag_image*my)),resample=Image.LANCZOS)#縦
            base.paste(resize_im2, (int(base_A4T_width/4 -im2_width*mag_image*my/2) , int(base_A4T_height/4*3 -im2_height*mag_image*my/2)))#縦
            
        elif im2_width > im2_height:
            resize_im2 = im2.resize((int(im2_width * mag_image2*mx) , int(im2_height * mag_image2*mx)),resample=Image.LANCZOS)#横
            base.paste(resize_im2, (int(base_A4T_width/4 -im2_width*mag_image2*mx/2) , int(base_A4T_height/4*3 -im2_height*mag_image2*mx/2)))#横

        j = j + 1
        im3 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j]))
        im3_width, im3_height = im3.size
        if im3_width < im3_height:
            resize_im3 = im3.resize((int(im3_width * mag_image*my) , int(im3_height * mag_image*my)),resample=Image.LANCZOS)#縦
            base.paste(resize_im3, (int(base_A4T_width/4*3 -im3_width*mag_image*my/2) , int(base_A4T_height/4 -im3_height*mag_image*my/2)))#縦
            
        elif im3_width > im3_height:
            resize_im3 = im3.resize((int(im3_width * mag_image2*mx) , int(im3_height * mag_image2*mx)),resample=Image.LANCZOS)#横
            base.paste(resize_im3, (int(base_A4T_width/4*3 -im3_width*mag_image2*mx/2) , int(base_A4T_height/4 -im3_height*mag_image2*mx/2)))#横
            
        j = j + 1
        im4 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j]))
        im4_width, im4_height = im4.size
        if im4_width < im4_height:
            resize_im4 = im4.resize((int(im4_width * mag_image*my) , int(im4_height * mag_image*my)),resample=Image.LANCZOS)#縦
            base.paste(resize_im4, (int(base_A4T_width/4*3 -im4_width*mag_image*my/2) , int(base_A4T_height/4*3 -im4_height*mag_image*my/2)))#縦
            
        elif im4_width > im4_height:
            resize_im4 = im4.resize((int(im4_width * mag_image2*mx) , int(im4_height * mag_image2*mx)),resample=Image.LANCZOS)#横
            base.paste(resize_im4, (int(base_A4T_width/4*3 -im4_width*mag_image2*mx/2) , int(base_A4T_height/4*3 -im4_height*mag_image2*mx/2)))#横

        base.save(os.path.join(img_dir_path,folder_list[i], pagename[n]+".jpg"), quality=100, dpi=(base_A4T_dpi, base_A4T_dpi))
        
    def r5(j,n,mx,my,mx2,my2):#右大き目の5枚

        chk_im = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j])) #このグループの1番目を判定するため読む
        chk_im_width, chk_im_height = chk_im.size
        chk_im2 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j+1])) #このグループの2番目を判定するため読む
        chk_im2_width, chk_im2_height = chk_im2.size
        chk_im3 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j+2])) #このグループの3番目を判定するため読む
        chk_im3_width, chk_im3_height = chk_im3.size
        chk_im4 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j+3])) #このグループの3番目を判定するため読む
        chk_im4_width, chk_im4_height = chk_im4.size
        chk_im5 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j+4])) #このグループの3番目を判定するため読む
        chk_im5_width, chk_im5_height = chk_im5.size
        
        if chk_im_width < chk_im_height:#1番目縦
            im = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j+1]))
            im2 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j+2]))
            im3 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j+3]))
            im4 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j+4]))
            im5 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j]))
        elif chk_im2_width < chk_im2_height:#2番目縦
            im = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j]))
            im2 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j+2]))
            im3 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j+3]))
            im4 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j+4]))
            im5 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j+1]))
        elif chk_im3_width < chk_im3_height:#3番目縦
            im = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j]))
            im2 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j+1]))
            im3 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j+3]))
            im4 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j+4]))
            im5 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j+2]))
        elif chk_im4_width < chk_im4_height:#4番目縦
            im = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j]))
            im2 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j+1]))
            im3 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j+2]))
            im4 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j+4]))
            im5 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j+3]))
        elif chk_im5_width < chk_im5_height:#5番目縦
            im = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j]))
            im2 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j+1]))
            im3 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j+2]))
            im4 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j+3]))
            im5 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j+4]))
        else:
            im = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j]))
            im2 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j+1]))
            im3 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j+2]))
            im4 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j+3]))
            im5 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j+4]))
            
        base = Image.new('RGB', (base_A4T_width, base_A4T_height), tuple_basecolor)#下地の白画像をbaseという名前で生成

        im_width, im_height = im.size
        if im_width < im_height:
            resize_im = im.resize((int(im_width * mag_image*my2) , int(im_height * mag_image*my2)),resample=Image.LANCZOS)#縦
            base.paste(resize_im, (int(base_A4T_width/8 -im_width*mag_image*my2/2) , int(base_A4T_height/4 -im_height*mag_image*my2/2)))#縦
            
        elif im_width > im_height:
            resize_im = im.resize((int(im_width * mag_image2*mx2) , int(im_height * mag_image2*mx2)),resample=Image.LANCZOS)#横
            base.paste(resize_im, (int(base_A4T_width/8 -im_width*mag_image2*mx2/2) , int(base_A4T_height/4 -im_height*mag_image2*mx2/2)))#横
            
        im2_width, im2_height = im2.size
        if im2_width < im2_height:
            resize_im2 = im2.resize((int(im2_width * mag_image*my2) , int(im2_height * mag_image*my2)),resample=Image.LANCZOS)#縦
            base.paste(resize_im2, (int(base_A4T_width/8 -im2_width*mag_image*my2/2) , int(base_A4T_height/4*3 -im2_height*mag_image*my2/2)))#縦
            
        elif im2_width > im2_height:
            resize_im2 = im2.resize((int(im2_width * mag_image2*mx2) , int(im2_height * mag_image2*mx2)),resample=Image.LANCZOS)#横
            base.paste(resize_im2, (int(base_A4T_width/8 -im2_width*mag_image2*mx2/2) , int(base_A4T_height/4*3 -im2_height*mag_image2*mx2/2)))#横
            
        im3_width, im3_height = im3.size
        if im3_width < im3_height:
            resize_im3 = im3.resize((int(im3_width * mag_image*my2) , int(im3_height * mag_image*my2)),resample=Image.LANCZOS)#縦
            base.paste(resize_im3, (int(base_A4T_width/8*3 -im3_width*mag_image*my2/2) , int(base_A4T_height/4 -im3_height*mag_image*my2/2)))#縦
            
        elif im3_width > im3_height:
            resize_im3 = im3.resize((int(im3_width * mag_image2*mx2) , int(im3_height * mag_image2*mx2)),resample=Image.LANCZOS)#横
            base.paste(resize_im3, (int(base_A4T_width/8*3 -im3_width*mag_image2*mx2/2) , int(base_A4T_height/4 -im3_height*mag_image2*mx2/2)))#横
            
        im4_width, im4_height = im4.size
        if im4_width < im4_height:
            resize_im4 = im4.resize((int(im4_width * mag_image*my2) , int(im4_height * mag_image*my2)),resample=Image.LANCZOS)#縦
            base.paste(resize_im4, (int(base_A4T_width/8*3 -im4_width*mag_image*my2/2) , int(base_A4T_height/4*3 -im4_height*mag_image*my2/2)))#縦
            
        elif im4_width > im4_height:
            resize_im4 = im4.resize((int(im4_width * mag_image2*mx2) , int(im4_height * mag_image2*mx2)),resample=Image.LANCZOS)#横
            base.paste(resize_im4, (int(base_A4T_width/8*3 -im4_width*mag_image2*mx2/2) , int(base_A4T_height/4*3 -im4_height*mag_image2*mx2/2)))#横
            
        im5_width, im5_height = im5.size
        if im5_width < im5_height:
            resize_im5 = im5.resize((int(im5_width * mag_image*my) , int(im5_height * mag_image*my)),resample=Image.LANCZOS)#縦
            base.paste(resize_im5, (int(base_A4T_width/4*3 -im5_width*mag_image*my/2) , int(base_A4T_height/2 -im5_height*mag_image*my/2)))#縦
            
        elif im5_width > im5_height:
            resize_im5 = im5.resize((int(im5_width * mag_image2*mx) , int(im5_height * mag_image2*mx)),resample=Image.LANCZOS)#横
            base.paste(resize_im5, (int(base_A4T_width/4*3 -im5_width*mag_image2*mx/2) , int(base_A4T_height/2 -im5_height*mag_image2*mx/2)))#横

        base.save(os.path.join(img_dir_path,folder_list[i], pagename[n]+".jpg"), quality=100, dpi=(base_A4T_dpi, base_A4T_dpi))
        
    def l5(j,n,mx,my,mx2,my2):#左大き目の5枚
        
        chk_im = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j])) #このグループの1番目を判定するため読む
        chk_im_width, chk_im_height = chk_im.size
        chk_im2 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j+1])) #このグループの2番目を判定するため読む
        chk_im2_width, chk_im2_height = chk_im2.size
        chk_im3 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j+2])) #このグループの3番目を判定するため読む
        chk_im3_width, chk_im3_height = chk_im3.size
        chk_im4 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j+3])) #このグループの3番目を判定するため読む
        chk_im4_width, chk_im4_height = chk_im4.size
        chk_im5 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j+4])) #このグループの3番目を判定するため読む
        chk_im5_width, chk_im5_height = chk_im5.size
        
        if chk_im_width < chk_im_height:#1番目縦
            im = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j]))
            im2 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j+1]))
            im3 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j+2]))
            im4 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j+3]))
            im5 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j+4]))
        elif chk_im2_width < chk_im2_height:#2番目縦
            im = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j+1]))
            im2 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j]))
            im3 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j+2]))
            im4 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j+3]))
            im5 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j+4]))
        elif chk_im3_width < chk_im3_height:#3番目縦
            im = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j+2]))
            im2 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j]))
            im3 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j+1]))
            im4 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j+3]))
            im5 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j+4]))
        elif chk_im4_width < chk_im4_height:#4番目縦
            im = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j+3]))
            im2 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j]))
            im3 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j+1]))
            im4 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j+2]))
            im5 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j+4]))
        elif chk_im5_width < chk_im5_height:#5番目縦
            im = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j+4]))
            im2 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j]))
            im3 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j+1]))
            im4 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j+2]))
            im5 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j+3]))
        else:
            im = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j]))
            im2 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j+1]))
            im3 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j+2]))
            im4 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j+3]))
            im5 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j+4]))
        base = Image.new('RGB', (base_A4T_width, base_A4T_height), tuple_basecolor)#下地の白画像をbaseという名前で生成

        im_width, im_height = im.size
        if im_width < im_height:
            resize_im = im.resize((int(im_width * mag_image*my) , int(im_height * mag_image*my)),resample=Image.LANCZOS)#縦
            base.paste(resize_im, (int(base_A4T_width/4 -im_width*mag_image*my/2) , int(base_A4T_height/2 -im_height*mag_image*my/2)))#縦
            
        elif im_width > im_height:
            resize_im = im.resize((int(im_width * mag_image2*mx) , int(im_height * mag_image2*mx)),resample=Image.LANCZOS)#横
            base.paste(resize_im, (int(base_A4T_width/4 -im_width*mag_image2*mx/2) , int(base_A4T_height/2 -im_height*mag_image2*mx/2)))#横
            
        im2_width, im2_height = im2.size
        if im2_width < im2_height:
            resize_im2 = im2.resize((int(im2_width * mag_image*my2) , int(im2_height * mag_image*my2)),resample=Image.LANCZOS)#縦
            base.paste(resize_im2, (int(base_A4T_width/8*5 -im2_width*mag_image*my2/2) , int(base_A4T_height/4 -im2_height*mag_image*my2/2)))#縦
            
        elif im2_width > im2_height:
            resize_im2 = im2.resize((int(im2_width * mag_image2*mx2) , int(im2_height * mag_image2*mx2)),resample=Image.LANCZOS)#横
            base.paste(resize_im2, (int(base_A4T_width/8*5 -im2_width*mag_image2*mx2/2) , int(base_A4T_height/4 -im2_height*mag_image2*mx2/2)))#横
            
        im3_width, im3_height = im3.size
        if im3_width < im3_height:
            resize_im3 = im3.resize((int(im3_width * mag_image*my2) , int(im3_height * mag_image*my2)),resample=Image.LANCZOS)#縦
            base.paste(resize_im3, (int(base_A4T_width/8*5 -im3_width*mag_image*my2/2) , int(base_A4T_height/4*3 -im3_height*mag_image*my2/2)))#縦
            
        elif im3_width > im3_height:
            resize_im3 = im3.resize((int(im3_width * mag_image2*mx2) , int(im3_height * mag_image2*mx2)),resample=Image.LANCZOS)#横
            base.paste(resize_im3, (int(base_A4T_width/8*5 -im3_width*mag_image2*mx2/2) , int(base_A4T_height/4*3 -im3_height*mag_image2*mx2/2)))#横
            
        im4_width, im4_height = im4.size
        if im4_width < im4_height:
            resize_im4 = im4.resize((int(im4_width * mag_image*my2) , int(im4_height * mag_image*my2)),resample=Image.LANCZOS)#縦
            base.paste(resize_im4, (int(base_A4T_width/8*7 -im4_width*mag_image*my2/2) , int(base_A4T_height/4 -im4_height*mag_image*my2/2)))#縦
            
        elif im4_width > im4_height:
            resize_im4 = im4.resize((int(im4_width * mag_image2*mx2) , int(im4_height * mag_image2*mx2)),resample=Image.LANCZOS)#横
            base.paste(resize_im4, (int(base_A4T_width/8*7 -im4_width*mag_image2*mx2/2) , int(base_A4T_height/4 -im4_height*mag_image2*mx2/2)))#横
            
        im5_width, im5_height = im5.size
        if im5_width < im5_height:
            resize_im5 = im5.resize((int(im5_width * mag_image*my2) , int(im5_height * mag_image*my2)),resample=Image.LANCZOS)#縦
            base.paste(resize_im5, (int(base_A4T_width/8*7 -im5_width*mag_image*my2/2) , int(base_A4T_height/4*3 -im5_height*mag_image*my2/2)))#縦
            
        elif im5_width > im5_height:
            resize_im5 = im5.resize((int(im5_width * mag_image2*mx2) , int(im5_height * mag_image2*mx2)),resample=Image.LANCZOS)#横
            base.paste(resize_im5, (int(base_A4T_width/8*7 -im5_width*mag_image2*mx2/2) , int(base_A4T_height/4*3 -im5_height*mag_image2*mx2/2)))#横

        base.save(os.path.join(img_dir_path,folder_list[i], pagename[n]+".jpg"), quality=100, dpi=(base_A4T_dpi, base_A4T_dpi))
        
    def l6(j,n,mx,my,mx2,my2):#6枚　右4枚　左2枚横優先

        flagH = 0
        chk_im = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j])) #このグループの1番目を判定するため読む
        
        chk_im_width, chk_im_height = chk_im.size
        if chk_im_height < chk_im_width:#1番目横
            imVH = 224 #横を数字大きく
            flagH = 1
        else:
            imVH = 6
        chk_im2 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j+1])) #このグループの2番目を判定するため読む
        
        chk_im2_width, chk_im2_height = chk_im2.size
        if chk_im2_height < chk_im2_width:#2番目横
            im2VH = 112 #横を数字大きく
            flagH = flagH+1
        else:
            im2VH = 5
        chk_im3 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j+2])) #このグループの3番目を判定するため読む
        
        chk_im3_width, chk_im3_height = chk_im3.size
        if chk_im3_height < chk_im3_width:#3番目横
            im3VH = 56 #横を数字大きく
            flagH = flagH+1
        else:
            im3VH = 4
        chk_im4 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j+3])) #このグループの4番目を判定するため読む
        
        chk_im4_width, chk_im4_height = chk_im4.size
        if chk_im4_height < chk_im4_width:#4番目横
            im4VH = 28 #横を数字大きく
            flagH = flagH+1
        else:
            im4VH = 3
        chk_im5 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j+4])) #このグループの5番目を判定するため読む
        
        chk_im5_width, chk_im5_height = chk_im5.size
        if chk_im5_height < chk_im5_width:#5番目横
            im5VH = 14 #横を数字大きく
            flagH = flagH+1
        else:
            im5VH = 2
        chk_im6 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j+5])) #このグループの6番目を判定するため読む
        
        chk_im6_width, chk_im6_height = chk_im6.size
        if chk_im6_height < chk_im6_width:#6番目横
            im6VH = 7 #横を数字大きく
            flagH = flagH+1
        else:
            im6VH = 1
        
        
        hlist = {0:imVH,1:im2VH,2:im3VH,3:im4VH,4:im5VH,5:im6VH}
        newlist = sorted(hlist.items(), key=lambda x:x[1],reverse=True)
        
        newlist0 = newlist[0]
        newlist1 = newlist[1]
        newlist2 = newlist[2]
        newlist3 = newlist[3]
        newlist4 = newlist[4]
        newlist5 = newlist[5]
        
        #yokoyoko = ["21","35","63","119","231","42","70","126","238","84","140","252","168","280","336"]
        #yokoyoko = [21,35,63,119,231,42,70,126,238,84,140,252,168,21,280,336]
        
        #先頭の2つの和がキー　値は先頭2つの組み合わせに対する123456の変化
        #yokoyoko = {21:123456,35:131456,63:142356,119:152346,231:162345,42:231456,70:130245,126:251346,238:261346,84:341256,140:351246,252:361245,168:451236,280:451235,336:561234}
        yokoyoko = {21:561234,35:461235,63:361245,119:261345,231:162345,42:451236,70:351246,126:251346,238:152346,84:341256,140:241356,252:142356,168:231456,280:132456,336:123456}
        test = newlist0[1] + newlist1[1]
        
        if flagH == 0:#横0は完全順列
            test2 = "123456"
        elif flagH == 1:#横1は左上のみ
            #横が1枚で
            if chk_im_width > chk_im_height:#1番目横
                test2 = "123456"
            elif chk_im2_width > chk_im2_height:#2番目横
                test2 = "213456"
            elif chk_im3_width > chk_im3_height:#3番目横
                test2 = "312456"
            elif chk_im4_width > chk_im4_height:#4番目横
                test2 = "412356"
            elif chk_im5_width > chk_im5_height:#5番目横
                test2 = "512346"
            else:#6番目
                test2 = "612345"
        else:#横2枚以上
            test5 = yokoyoko[test]
        
            test2 = str(test5)
        
        jc1 = int(test2[0])
        jc2 = int(test2[1])
        jc3 = int(test2[2])
        jc4 = int(test2[3])
        jc5 = int(test2[4])
        jc6 = int(test2[5])
        
        im = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j+jc1-1]))
        im2 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j+jc2-1]))
        im3 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j+jc3-1]))
        im4 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j+jc4-1]))
        im5 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j+jc5-1]))
        im6 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j+jc6-1]))
        
            
        base = Image.new('RGB', (base_A4T_width, base_A4T_height), tuple_basecolor)#下地の白画像をbaseという名前で生成

        im_width, im_height = im.size
        if im_width < im_height:
            resize_im = im.resize((int(im_width * mag_image*my) , int(im_height * mag_image*my)),resample=Image.LANCZOS)#縦
            base.paste(resize_im, (int(base_A4T_width/4 -im_width*mag_image*my/2) , int(base_A4T_height/4 -im_height*mag_image*my/2)))#縦
            
        elif im_width > im_height:
            resize_im = im.resize((int(im_width * mag_image2*mx) , int(im_height * mag_image2*mx)),resample=Image.LANCZOS)#横
            base.paste(resize_im, (int(base_A4T_width/4 -im_width*mag_image2*mx/2) , int(base_A4T_height/4 -im_height*mag_image2*mx/2)))#横
        
        im2_width, im2_height = im2.size
        if im2_width < im2_height:
            resize_im2 = im2.resize((int(im2_width * mag_image*my) , int(im2_height * mag_image*my)),resample=Image.LANCZOS)#縦
            base.paste(resize_im2, (int(base_A4T_width/4 -im2_width*mag_image*my/2) , int(base_A4T_height/4*3 -im2_height*mag_image*my/2)))#縦
            
        elif im2_width > im2_height:
            resize_im2 = im2.resize((int(im2_width * mag_image2*mx) , int(im2_height * mag_image2*mx)),resample=Image.LANCZOS)#横
            base.paste(resize_im2, (int(base_A4T_width/4 -im2_width*mag_image2*mx/2) , int(base_A4T_height/4*3 -im2_height*mag_image2*mx/2)))#横
        
        im3_width, im3_height = im3.size
        if im3_width < im3_height:
            resize_im3 = im3.resize((int(im3_width * mag_image*my2) , int(im3_height * mag_image*my2)),resample=Image.LANCZOS)#縦
            base.paste(resize_im3, (int(base_A4T_width/8*5 -im3_width*mag_image*my2/2) , int(base_A4T_height/4 -im3_height*mag_image*my2/2)))#縦
            
        elif im3_width > im3_height:
            resize_im3 = im3.resize((int(im3_width * mag_image2*mx2) , int(im3_height * mag_image2*mx2)),resample=Image.LANCZOS)#横
            base.paste(resize_im3, (int(base_A4T_width/8*5 -im3_width*mag_image2*mx2/2) , int(base_A4T_height/4 -im3_height*mag_image2*mx2/2)))#横
            
        im4_width, im4_height = im4.size
        if im4_width < im4_height:
            resize_im4 = im4.resize((int(im4_width * mag_image*my2) , int(im4_height * mag_image*my2)),resample=Image.LANCZOS)#縦
            base.paste(resize_im4, (int(base_A4T_width/8*5 -im4_width*mag_image*my2/2) , int(base_A4T_height/4*3 -im4_height*mag_image*my2/2)))#縦
            
        elif im4_width > im4_height:
            resize_im4 = im4.resize((int(im4_width * mag_image2*mx2) , int(im4_height * mag_image2*mx2)),resample=Image.LANCZOS)#横
            base.paste(resize_im4, (int(base_A4T_width/8*5 -im4_width*mag_image2*mx2/2) , int(base_A4T_height/4*3 -im4_height*mag_image2*mx2/2)))#横

        im5_width, im5_height = im5.size
        if im5_width < im5_height:
            resize_im5 = im5.resize((int(im5_width * mag_image*my2) , int(im5_height * mag_image*my2)),resample=Image.LANCZOS)#縦
            base.paste(resize_im5, (int(base_A4T_width/8*7 -im5_width*mag_image*my2/2) , int(base_A4T_height/4 -im5_height*mag_image*my2/2)))#縦
            
        elif im5_width > im5_height:
            resize_im5 = im5.resize((int(im5_width * mag_image2*mx2) , int(im5_height * mag_image2*mx2)),resample=Image.LANCZOS)#横
            base.paste(resize_im5, (int(base_A4T_width/8*7 -im5_width*mag_image2*mx2/2) , int(base_A4T_height/4 -im5_height*mag_image2*mx2/2)))#横
            
        im6_width, im6_height = im6.size
        if im6_width < im6_height:
            resize_im6 = im6.resize((int(im6_width * mag_image*my2) , int(im6_height * mag_image*my2)),resample=Image.LANCZOS)#縦
            base.paste(resize_im6, (int(base_A4T_width/8*7 -im6_width*mag_image*my2/2) , int(base_A4T_height/4*3 -im6_height*mag_image*my2/2)))#縦
            
        elif im6_width > im6_height:
            resize_im6 = im6.resize((int(im6_width * mag_image2*mx2) , int(im6_height * mag_image2*mx2)),resample=Image.LANCZOS)#横
            base.paste(resize_im6, (int(base_A4T_width/8*7 -im6_width*mag_image2*mx2/2) , int(base_A4T_height/4*3 -im6_height*mag_image2*mx2/2)))#横


        base.save(os.path.join(img_dir_path,folder_list[i], pagename[n]+".jpg"), quality=100, dpi=(base_A4T_dpi, base_A4T_dpi))
        
    def r6(j,n,mx,my,mx2,my2):#6枚　左4枚中　右2枚大　横優先

        flagH = 0
        chk_im = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j])) #このグループの1番目を判定するため読む
        chk_im_width, chk_im_height = chk_im.size
        if chk_im_height < chk_im_width:#1番目横
            imVH = 224 #横を数字大きく
            flagH = 1
        else:
            imVH = 6
        chk_im2 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j+1])) #このグループの2番目を判定するため読む
        chk_im2_width, chk_im2_height = chk_im2.size
        if chk_im2_height < chk_im2_width:#2番目横
            im2VH = 112 #横を数字大きく
            flagH = flagH+1
        else:
            im2VH = 5
        chk_im3 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j+2])) #このグループの3番目を判定するため読む
        chk_im3_width, chk_im3_height = chk_im3.size
        if chk_im3_height < chk_im3_width:#3番目横
            im3VH = 56 #横を数字大きく
            flagH = flagH+1
        else:
            im3VH = 4
        chk_im4 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j+3])) #このグループの4番目を判定するため読む
        chk_im4_width, chk_im4_height = chk_im4.size
        if chk_im4_height < chk_im4_width:#4番目横
            im4VH = 28 #横を数字大きく
            flagH = flagH+1
        else:
            im4VH = 3
        chk_im5 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j+4])) #このグループの5番目を判定するため読む
        chk_im5_width, chk_im5_height = chk_im5.size
        if chk_im5_height < chk_im5_width:#5番目横
            im5VH = 14 #横を数字大きく
            flagH = flagH+1
        else:
            im5VH = 2
        chk_im6 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j+5])) #このグループの6番目を判定するため読む
        chk_im6_width, chk_im6_height = chk_im6.size
        if chk_im6_height < chk_im6_width:#6番目横
            im6VH = 7 #横を数字大きく
            flagH = flagH+1
        else:
            im6VH = 1
        
        hlist = {0:imVH,1:im2VH,2:im3VH,3:im4VH,4:im5VH,5:im6VH}
        newlist = sorted(hlist.items(), key=lambda x:x[1],reverse=False)	#小さい順に前から、横は後ろにまとまる
        
        newlist0 = newlist[0]
        newlist1 = newlist[1]
        newlist2 = newlist[2]
        newlist3 = newlist[3]
        newlist4 = newlist[4]
        newlist5 = newlist[5]
        
        #最後の2つの和がキー　値は最後2つの組み合わせに対する123456の変化
        
        yokoyoko = {21:123456,35:123546,63:124536,119:134526,231:234516,42:123645,70:124635,126:134625,238:234615,84:125634,140:135624,252:235614,168:145623,280:245613,336:345612}
        test = newlist4[1] + newlist5[1]
        
        if flagH == 0:#横0は完全順列
            test2 = "123456"
        elif flagH == 1:#横1は右下のみ
            #横が1枚で
            if chk_im_width > chk_im_height:#1番目横
                test2 = "234561"
            elif chk_im2_width > chk_im2_height:#2番目横
                test2 = "134562"
            elif chk_im3_width > chk_im3_height:#3番目横
                test2 = "124563"
            elif chk_im4_width > chk_im4_height:#4番目横
                test2 = "123564"
            elif chk_im5_width > chk_im5_height:#5番目横
                test2 = "123465"
            else:#6番目
                test2 = "123456"
        else:#横2枚以上
            test5 = yokoyoko[test]
            
        
            test2 = str(test5)
        
        jc1 = int(test2[0])
        jc2 = int(test2[1])
        jc3 = int(test2[2])
        jc4 = int(test2[3])
        jc5 = int(test2[4])
        jc6 = int(test2[5])

        
        im = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j+jc1-1]))
        im2 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j+jc2-1]))
        im3 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j+jc3-1]))
        im4 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j+jc4-1]))
        im5 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j+jc5-1]))
        im6 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j+jc6-1]))
        
            
        base = Image.new('RGB', (base_A4T_width, base_A4T_height), tuple_basecolor)#下地の白画像をbaseという名前で生成

        im_width, im_height = im.size
        if im_width < im_height:
            resize_im = im.resize((int(im_width * mag_image*my2) , int(im_height * mag_image*my2)),resample=Image.LANCZOS)#縦
            base.paste(resize_im, (int(base_A4T_width/8 -im_width*mag_image*my2/2) , int(base_A4T_height/4 -im_height*mag_image*my2/2)))#縦
            
        elif im_width > im_height:
            resize_im = im.resize((int(im_width * mag_image2*mx2) , int(im_height * mag_image2*mx2)),resample=Image.LANCZOS)#横
            base.paste(resize_im, (int(base_A4T_width/8 -im_width*mag_image2*mx2/2) , int(base_A4T_height/4 -im_height*mag_image2*mx2/2)))#横
        
        im2_width, im2_height = im2.size
        if im2_width < im2_height:
            resize_im2 = im2.resize((int(im2_width * mag_image*my2) , int(im2_height * mag_image*my2)),resample=Image.LANCZOS)#縦
            base.paste(resize_im2, (int(base_A4T_width/8 -im2_width*mag_image*my2/2) , int(base_A4T_height/4*3 -im2_height*mag_image*my2/2)))#縦
            
        elif im2_width > im2_height:
            resize_im2 = im2.resize((int(im2_width * mag_image2*mx2) , int(im2_height * mag_image2*mx2)),resample=Image.LANCZOS)#横
            base.paste(resize_im2, (int(base_A4T_width/8 -im2_width*mag_image2*mx2/2) , int(base_A4T_height/4*3 -im2_height*mag_image2*mx2/2)))#横
        
        im3_width, im3_height = im3.size
        if im3_width < im3_height:
            resize_im3 = im3.resize((int(im3_width * mag_image*my2) , int(im3_height * mag_image*my2)),resample=Image.LANCZOS)#縦
            base.paste(resize_im3, (int(base_A4T_width/8*3 -im3_width*mag_image*my2/2) , int(base_A4T_height/4 -im3_height*mag_image*my2/2)))#縦
            
        elif im3_width > im3_height:
            resize_im3 = im3.resize((int(im3_width * mag_image2*mx2) , int(im3_height * mag_image2*mx2)),resample=Image.LANCZOS)#横
            base.paste(resize_im3, (int(base_A4T_width/8*3 -im3_width*mag_image2*mx2/2) , int(base_A4T_height/4 -im3_height*mag_image2*mx2/2)))#横
            
        im4_width, im4_height = im4.size
        if im4_width < im4_height:
            resize_im4 = im4.resize((int(im4_width * mag_image*my2) , int(im4_height * mag_image*my2)),resample=Image.LANCZOS)#縦
            base.paste(resize_im4, (int(base_A4T_width/8*3 -im4_width*mag_image*my2/2) , int(base_A4T_height/4*3 -im4_height*mag_image*my2/2)))#縦
            
        elif im4_width > im4_height:
            resize_im4 = im4.resize((int(im4_width * mag_image2*mx2) , int(im4_height * mag_image2*mx2)),resample=Image.LANCZOS)#横
            base.paste(resize_im4, (int(base_A4T_width/8*3 -im4_width*mag_image2*mx2/2) , int(base_A4T_height/4*3 -im4_height*mag_image2*mx2/2)))#横

        im5_width, im5_height = im5.size
        if im5_width < im5_height:
            resize_im5 = im5.resize((int(im5_width * mag_image*my) , int(im5_height * mag_image*my)),resample=Image.LANCZOS)#縦
            base.paste(resize_im5, (int(base_A4T_width/4*3 -im5_width*mag_image*my/2) , int(base_A4T_height/4 -im5_height*mag_image*my/2)))#縦
            
        elif im5_width > im5_height:
            resize_im5 = im5.resize((int(im5_width * mag_image2*mx) , int(im5_height * mag_image2*mx)),resample=Image.LANCZOS)#横
            base.paste(resize_im5, (int(base_A4T_width/4*3 -im5_width*mag_image2*mx/2) , int(base_A4T_height/4 -im5_height*mag_image2*mx/2)))#横
            
        im6_width, im6_height = im6.size
        if im6_width < im6_height:
            resize_im6 = im6.resize((int(im6_width * mag_image*my) , int(im6_height * mag_image*my)),resample=Image.LANCZOS)#縦
            base.paste(resize_im6, (int(base_A4T_width/4*3 -im6_width*mag_image*my/2) , int(base_A4T_height/4*3 -im6_height*mag_image*my/2)))#縦
            
        elif im6_width > im6_height:
            resize_im6 = im6.resize((int(im6_width * mag_image2*mx) , int(im6_height * mag_image2*mx)),resample=Image.LANCZOS)#横
            base.paste(resize_im6, (int(base_A4T_width/4*3 -im6_width*mag_image2*mx/2) , int(base_A4T_height/4*3 -im6_height*mag_image2*mx/2)))#横


        base.save(os.path.join(img_dir_path,folder_list[i], pagename[n]+".jpg"), quality=100, dpi=(base_A4T_dpi, base_A4T_dpi))

   
        
    def n8(j,n,mx,my):#8枚

        base = Image.new('RGB', (base_A4T_width, base_A4T_height), tuple_basecolor)#下地の白画像をbaseという名前で生成

        im = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j]))
        im_width, im_height = im.size
        if im_width < im_height:
            resize_im = im.resize((int(im_width * mag_image*my) , int(im_height * mag_image*my)),resample=Image.LANCZOS)#縦
            base.paste(resize_im, (int(base_A4T_width/8 -im_width*mag_image*my/2) , int(base_A4T_height/4 -im_height*mag_image*my/2)))#縦
            
        elif im_width > im_height:
            resize_im = im.resize((int(im_width * mag_image2*mx) , int(im_height * mag_image2*mx)),resample=Image.LANCZOS)#横
            base.paste(resize_im, (int(base_A4T_width/8 -im_width*mag_image2*mx/2) , int(base_A4T_height/4 -im_height*mag_image2*mx/2)))#横
            
        j = j + 1
        im2 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j]))
        im2_width, im2_height = im2.size
        if im2_width < im2_height:
            resize_im2 = im2.resize((int(im2_width * mag_image*my) , int(im2_height * mag_image*my)),resample=Image.LANCZOS)#縦
            base.paste(resize_im2, (int(base_A4T_width/8 -im2_width*mag_image*my/2) , int(base_A4T_height/4*3 -im2_height*mag_image*my/2)))#縦
            
        elif im2_width > im2_height:
            resize_im2 = im2.resize((int(im2_width * mag_image2*mx) , int(im2_height * mag_image2*mx)),resample=Image.LANCZOS)#横
            base.paste(resize_im2, (int(base_A4T_width/8 -im2_width*mag_image2*mx/2) , int(base_A4T_height/4*3 -im2_height*mag_image2*mx/2)))#横
            
        j = j + 1
        im3 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j]))
        im3_width, im3_height = im3.size
        if im3_width < im3_height:
            resize_im3 = im3.resize((int(im3_width * mag_image*my) , int(im3_height * mag_image*my)),resample=Image.LANCZOS)#縦
            base.paste(resize_im3, (int(base_A4T_width/8*3 -im3_width*mag_image*my/2) , int(base_A4T_height/4 -im3_height*mag_image*my/2)))#縦
            
        elif im3_width > im3_height:
            resize_im3 = im3.resize((int(im3_width * mag_image2*mx) , int(im3_height * mag_image2*mx)),resample=Image.LANCZOS)#横
            base.paste(resize_im3, (int(base_A4T_width/8*3 -im3_width*mag_image2*mx/2) , int(base_A4T_height/4 -im3_height*mag_image2*mx/2)))#横
            
        j = j + 1
        im4 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j]))
        im4_width, im4_height = im4.size
        if im4_width < im4_height:
            resize_im4 = im4.resize((int(im4_width * mag_image*my) , int(im4_height * mag_image*my)),resample=Image.LANCZOS)#縦
            base.paste(resize_im4, (int(base_A4T_width/8*3 -im4_width*mag_image*my/2) , int(base_A4T_height/4*3 -im4_height*mag_image*my/2)))#縦
            
        elif im4_width > im4_height:
            resize_im4 = im4.resize((int(im4_width * mag_image2*mx) , int(im4_height * mag_image2*mx)),resample=Image.LANCZOS)#横
            base.paste(resize_im4, (int(base_A4T_width/8*3 -im4_width*mag_image2*mx/2) , int(base_A4T_height/4*3 -im4_height*mag_image2*mx/2)))#横

        j = j + 1
        im5 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j]))
        im5_width, im5_height = im5.size
        if im5_width < im5_height:
            resize_im5 = im5.resize((int(im5_width * mag_image*my) , int(im5_height * mag_image*my)),resample=Image.LANCZOS)#縦
            base.paste(resize_im5, (int(base_A4T_width/8*5 -im5_width*mag_image*my/2) , int(base_A4T_height/4 -im5_height*mag_image*my/2)))#縦
            
        elif im5_width > im5_height:
            resize_im5 = im5.resize((int(im5_width * mag_image2*mx) , int(im5_height * mag_image2*mx)),resample=Image.LANCZOS)#横
            base.paste(resize_im5, (int(base_A4T_width/8*5 -im5_width*mag_image2*mx/2) , int(base_A4T_height/4 -im5_height*mag_image2*mx/2)))#横
            
        j = j + 1
        im6 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j]))
        im6_width, im6_height = im6.size
        if im6_width < im6_height:
            resize_im6 = im6.resize((int(im6_width * mag_image*my) , int(im6_height * mag_image*my)),resample=Image.LANCZOS)#縦
            base.paste(resize_im6, (int(base_A4T_width/8*5 -im6_width*mag_image*my/2) , int(base_A4T_height/4*3 -im6_height*mag_image*my/2)))#縦
            
        elif im6_width > im6_height:
            resize_im6 = im6.resize((int(im6_width * mag_image2*mx) , int(im6_height * mag_image2*mx)),resample=Image.LANCZOS)#横
            base.paste(resize_im6, (int(base_A4T_width/8*5 -im6_width*mag_image2*mx/2) , int(base_A4T_height/4*3 -im6_height*mag_image2*mx/2)))#横
            
        j = j + 1
        im7 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j]))
        im7_width, im7_height = im7.size
        if im7_width < im7_height:
            resize_im7 = im7.resize((int(im7_width * mag_image*my) , int(im7_height * mag_image*my)),resample=Image.LANCZOS)#縦
            base.paste(resize_im7, (int(base_A4T_width/8*7 -im7_width*mag_image*my/2) , int(base_A4T_height/4 -im7_height*mag_image*my/2)))#縦
            
        elif im7_width > im7_height:
            resize_im7 = im7.resize((int(im7_width * mag_image2*mx) , int(im7_height * mag_image2*mx)),resample=Image.LANCZOS)#横
            base.paste(resize_im7, (int(base_A4T_width/8*7 -im7_width*mag_image2*mx/2) , int(base_A4T_height/4 -im7_height*mag_image2*mx/2)))#横
            
        j = j + 1
        im8 = Image.open(os.path.join(img_dir_path,folder_list[i],"other",sorted_directory[j]))
        im8_width, im8_height = im8.size
        if im8_width < im8_height:
            resize_im8 = im8.resize((int(im8_width * mag_image*my) , int(im8_height * mag_image*my)),resample=Image.LANCZOS)#縦
            base.paste(resize_im8, (int(base_A4T_width/8*7 -im8_width*mag_image*my/2) , int(base_A4T_height/4*3 -im8_height*mag_image*my/2)))#縦
            
        elif im8_width > im8_height:
            resize_im8 = im8.resize((int(im8_width * mag_image2*mx) , int(im8_height * mag_image2*mx)),resample=Image.LANCZOS)#横
            base.paste(resize_im8, (int(base_A4T_width/8*7 -im8_width*mag_image2*mx/2) , int(base_A4T_height/4*3 -im8_height*mag_image2*mx/2)))#横


        base.save(os.path.join(img_dir_path,folder_list[i], pagename[n]+".jpg"), quality=100, dpi=(base_A4T_dpi, base_A4T_dpi))
    #j:今何枚目？　x:片面ページで1か3　n:ファイル名(0001⇒1　2600⇒14) mx my:ページ固有の画像倍率
    if albumname == '50':
        single1(0,1,3)
        l3(1,2,0.9,0.47)
        #l6(4,3,0.9,0.47,0.5,0.47)#
        #l6(10,4,0.9,0.47,0.5,0.47)#
        #l6(16,5,0.9,0.47,0.5,0.47)#
        #l6(22,6,0.9,0.47,0.5,0.47)#
        #l6(28,7,0.9,0.47,0.5,0.47)#
        #l6(34,8,0.9,0.47,0.5,0.47)#
        #l6(40,9,0.9,0.47,0.5,0.47)#

        l5(4,3,1.0,1.0,0.5,0.47)
        r3(9,4,0.9,0.47)
        n4(12,5,0.9,0.47)
        l3(16,6,0.9,0.47)
        r6(19,7,0.9,0.47,0.5,0.47)
        l3(25,8,0.9,0.47)
        l6(28,9,0.9,0.47,0.5,0.47)
        r3(34,10,0.9,0.47)
        l5(37,11,1.0,1.0,0.5,0.47)
        r3(42,12,0.9,0.47)
        
        if (os.path.exists(cover_chk) == False):#レザーなら最後の2枚変化
            n4(45,13,0.9,0.47)
            single1(49,14,1)
        else:
            l3(45,13,0.9,0.47)
            single1(48,14,1)
        
    elif albumname == '75':
        single1(0,1,3)
        l3(1,2,0.9,0.47)
        r5(4,3,1.0,1.0,0.5,0.47)
        r3(9,4,0.9,0.47)
        l5(12,5,1.0,1.0,0.5,0.47)
        l6(17,6,0.9,0.47,0.5,0.47)
        l5(23,7,1.0,1.0,0.5,0.47)
        r6(28,8,0.9,0.47,0.5,0.47)
        l3(34,9,0.9,0.47)
        l6(37,10,0.9,0.47,0.5,0.47)
        n8(43,11,0.5,0.47)
        l6(51,12,0.9,0.47,0.5,0.47)
        l5(57,13,1.0,1.0,0.5,0.47)
        n8(62,14,0.5,0.47)
        
        if (os.path.exists(cover_chk) == False):#レザーなら最後の2枚変化
            n4(70,15,0.9,0.47)
            single1(74,16,1)
        else:
            r3(70,15,0.9,0.47)
            single1(73,16,1)
        
    else:
        print('規定外のアルバム')
        
    

    print('進捗度',end=' ')
    print( str(round(100 * (i+1)/(len(folder_list)),1,)),end='')
    print('%')

    i = i + 1 #画像の行数によって値を変えてください


    
root.quit()#この処理のせいでエラーメッセージが出ますが、スルーしてOKです。
exit()#この処理のせいでエラーメッセージが出ますが、スルーしてOKです。
# Out:
# 1115473_20201002oh0121307574_n_663438_75 75カット ナチュラルアルバムA4縦 進捗度 7.7%
# 1313531_20200925jj0621149242_n_661022_50 50カット ナチュラルアルバムA4縦 進捗度 15.4%
# 1315075_20200927ybb052127891_n_661966_75 75カット ナチュラルアルバムA4縦 進捗度 23.1%
# 1317159_20200927jw0221361426_n_661762_75 75カット ナチュラルアルバムA4縦 進捗度 30.8%
# 1507543_20201003yc0921315254_f_664254_50 50カット アルバムファイン 進捗度 38.5%
# 1511262_100⇒75間引き済み_20201001ydd072131220_n_663406_75 75カット ナチュラルアルバムA4縦 進捗度 46.2%
# 1521605_20200927ydd072127967_v_662062_50 50カット バリューアルバム 裏表紙小画像なし 進捗度 53.8%
# 1715223_20200925nc0121298718_n_660802_75 75カット ナチュラルアルバムA4縦 進捗度 61.5%
# 1715305_20201002na0321308334_n_663462_75 75カット ナチュラルアルバムA4縦 進捗度 69.2%
# 1715343_20201004nn0721343562_f_664734_50 50カット アルバムファイン 進捗度 76.9%
# 1905982_20201003kco092128833_n_664214_50 50カット ナチュラルアルバムA4縦 進捗度 84.6%
# 1910509_20200926kso012102793_v_661222_75 75カット バリューアルバム 裏表紙小画像なし 進捗度 92.3%
# 1910548_20200929kso072127881_v_662778_50 50カット バリューアルバム 裏表紙小画像なし 進捗度 100.0%
